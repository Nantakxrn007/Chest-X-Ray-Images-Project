# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("GPU is available")
else:
    device = torch.device("cpu")
    print("GPU not available, using CPU")

print("Number of GPUs:", torch.cuda.device_count())

if torch.cuda.is_available():
    print("Current GPU:", torch.cuda.get_device_name(0))
# Out:
# GPU is available
# Number of GPUs: 1
# Current GPU: NVIDIA GeForce RTX 2050

# %%
base_dir = os.path.join(path, "chest_xray")
print(os.listdir(base_dir))  # ['train', 'test', 'val']

train_dir = os.path.join(base_dir, "train")
print(os.listdir(train_dir))  # ['NORMAL', 'PNEUMONIA']

normal_dir = os.path.join(train_dir, "NORMAL")
pneumonia_dir = os.path.join(train_dir, "PNEUMONIA")
# Out:
# ['chest_xray', 'test', 'train', 'val', '__MACOSX']
# ['NORMAL', 'PNEUMONIA']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

sample_image_path = os.path.join(normal_dir, os.listdir(normal_dir)[0])
img = mpimg.imread(sample_image_path)

plt.imshow(img, cmap='gray')
plt.title("Normal X-Ray Example")
plt.axis("off")
plt.show()

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),  
    transforms.ToTensor(),          
    transforms.Normalize([0.5], [0.5])  
])
